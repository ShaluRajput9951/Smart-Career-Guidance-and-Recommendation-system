# %%
import tkinter as tk
from tkinter import *
from tkinter import messagebox

root = Tk()
root.title('Career recomendation System')
root.geometry('700x500')
Label(root, text='\n\nCAREER RECOMENDATION SYSTEM\n', font=("Times", 30),bg="skyblue").pack()
frame = Frame(root).pack()
def gui():
    new=Tk()
    new.title('course')
    new.geometry('500x500')
    Label(new, text='\n Select course u currently completed :\n', font=("Times", 20),fg="black").pack()
    tenth_button = Button(new, text='10th', fg='#6ab04c', width=16, bg="White", font=("Comic sans ms", 16), command=tenth).pack(pady=20, padx=10)
    tw_button = Button(new, text='12th', fg='#6ab04c', width=16, bg="White", font=("Comic sans ms", 16), command=tw).pack(pady=20, padx=10)
    AG_button = Button(new, text='Bachelor Degree', fg='#6ab04c', width=16, bg="White", font=("Comic sans ms", 16), command=ag).pack(pady=20, padx=10)

def ag():
    new=Tk()
    new.title('after graduation :')
    new.geometry('500x500')  
    Label(new, text='after Graduation :', font=("Times", 10),fg="black").grid()
    Label(new, text='1   Master degree', font=("Times", 20),fg="Red").grid(column=2,row=1)
    Label(new, text='course', font=("Times", 10),fg="Red").grid(row=3,column=1)
    Label(new, text=' Duration', font=("Times", 10),fg="red").grid(row=3,column=3)
    Label(new, text='Mtech', font=("Times", 10),fg="black").grid(row=4,column=1)
    Label(new, text=' 2', font=("Times", 10),fg="black").grid(row=4,column=3)
    Label(new, text='Msc', font=("Times", 10),fg="black").grid(row=5,column=1)
    Label(new, text=' 3', font=("Times", 10),fg="black").grid(row=5,column=3)
    Label(new, text='MBA', font=("Times", 10),fg="black").grid(row=6,column=1)
    Label(new, text=' 2', font=("Times", 10),fg="black").grid(row=6,column=3)
    Label(new, text='MA', font=("Times", 10),fg="black").grid(row=7,column=1)
    Label(new, text=' 2', font=("Times", 10),fg="black").grid(row=7,column=3)
    next_button = Button(new, text='HOME', fg='#6ab04c', width=10, bg="White", font=("Comic sans ms", 10), command=gui).grid(row=16, column=3)
    back_button = Button(new, text='Back', fg='#6ab04c', width=10, bg="White", font=("Comic sans ms", 10), command=gui).grid(row=16, column=1)

    

    
def next():
    new=Tk()
    new.title('after twelth')
    new.geometry('500x500')  
    Label(new, text='after 12th :', font=("Times", 10),fg="black").grid()
    Label(new, text='3   BCOM', font=("Times", 20),fg="Red").grid(column=2,row=1)
    Label(new, text='course', font=("Times", 10),fg="Red").grid(row=3,column=1)
    Label(new, text=' Duration', font=("Times", 10),fg="red").grid(row=3,column=3)
    Label(new, text='Accounting', font=("Times", 10),fg="black").grid(row=4,column=1)
    Label(new, text=' 3', font=("Times", 10),fg="black").grid(row=4,column=3)
    Label(new, text='Finance', font=("Times", 10),fg="black").grid(row=5,column=1)
    Label(new, text=' 3', font=("Times", 10),fg="black").grid(row=5,column=3)
    Label(new, text='Management', font=("Times", 10),fg="black").grid(row=6,column=1)
    Label(new, text=' 3', font=("Times", 10),fg="black").grid(row=6,column=3)
    Label(new, text='Human Resource', font=("Times", 10),fg="black").grid(row=7,column=1)
    Label(new, text=' 3', font=("Times", 10),fg="black").grid(row=7,column=3)
    
    Label(new, text='4   BA', font=("Times", 20),fg="Red").grid(column=2,row=9)
    Label(new, text='course', font=("Times", 10),fg="red").grid(row=10,column=1)
    Label(new, text=' Duration', font=("Times", 10),fg="red").grid(row=10,column=3)
    Label(new, text='BA english', font=("Times", 10),fg="black").grid(row=11,column=1)
    Label(new, text=' 3', font=("Times", 10),fg="black").grid(row=11,column=3)
    Label(new, text='BA History', font=("Times", 10),fg="black").grid(row=12,column=1)
    Label(new, text=' 3', font=("Times", 10),fg="black").grid(row=12,column=3)
    Label(new, text='BA Economics', font=("Times", 10),fg="black").grid(row=13,column=1)
    Label(new, text=' 3', font=("Times", 10),fg="black").grid(row=13,column=3)
    Label(new, text='BA Political', font=("Times", 10),fg="black").grid(row=14,column=1)
    Label(new, text=' 3', font=("Times", 10),fg="black").grid(row=14,column=3)
    Label(new, text='BA social', font=("Times", 10),fg="black").grid(row=15,column=1)
    Label(new, text=' 3', font=("Times", 10),fg="black").grid(row=15,column=3)   
    Home_button = Button(new, text='Back', fg='#6ab04c', width=16, bg="White", font=("Comic sans ms", 16), command=tw).grid(row=16, column=2)

    
def tw():
    new=Tk()
    new.title('after twelth')
    new.geometry('500x500')  
    Label(new, text='after 12th :', font=("Times", 10),fg="black").grid()
    Label(new, text='1   Btech', font=("Times", 20),fg="Red").grid(column=2,row=1)
    Label(new, text='course', font=("Times", 10),fg="red").grid(row=3,column=1)
    Label(new, text=' Duration', font=("Times", 10),fg="red").grid(row=3,column=3)
    Label(new, text='CSE', font=("Times", 10),fg="black").grid(row=4,column=1)
    Label(new, text=' 4', font=("Times", 10),fg="black").grid(row=4,column=3)
    Label(new, text='CE', font=("Times", 10),fg="black").grid(row=5,column=1)
    Label(new, text=' 4', font=("Times", 10),fg="black").grid(row=5,column=3)
    Label(new, text='EE', font=("Times", 10),fg="black").grid(row=6,column=1)
    Label(new, text=' 4', font=("Times", 10),fg="black").grid(row=6,column=3)
    Label(new, text='ME', font=("Times", 10),fg="black").grid(row=7,column=1)
    Label(new, text=' 4', font=("Times", 10),fg="black").grid(row=7,column=3)
    
    Label(new, text='2   BSC', font=("Times", 20),fg="Red").grid(column=2,row=9)
    Label(new, text='course', font=("Times", 10),fg="red").grid(row=10,column=1)
    Label(new, text=' Duration', font=("Times", 10),fg="red").grid(row=10,column=3)
    Label(new, text='Agriculture', font=("Times", 10),fg="black").grid(row=11,column=1)
    Label(new, text=' 3', font=("Times", 10),fg="black").grid(row=11,column=3)
    Label(new, text='Animation', font=("Times", 10),fg="black").grid(row=12,column=1)
    Label(new, text=' 3', font=("Times", 10),fg="black").grid(row=12,column=3)
    Label(new, text='Biochemistry', font=("Times", 10),fg="black").grid(row=13,column=1)
    Label(new, text=' 3', font=("Times", 10),fg="black").grid(row=13,column=3)
    Label(new, text='Bioinformatics', font=("Times", 10),fg="black").grid(row=14,column=1)
    Label(new, text=' 3', font=("Times", 10),fg="black").grid(row=14,column=3)
    Label(new, text='Dietetics', font=("Times", 10),fg="black").grid(row=15,column=1)
    Label(new, text=' 3', font=("Times", 10),fg="black").grid(row=15,column=3)    
    next_button = Button(new, text='Next', fg='#6ab04c', width=10, bg="White", font=("Comic sans ms", 10), command=next).grid(row=16, column=3)
    back_button = Button(new, text='Back', fg='#6ab04c', width=10, bg="White", font=("Comic sans ms", 10), command=gui).grid(row=16, column=1)

def tenth():
    new=Tk()
    new.title('Tenth')
    new.geometry('500x500')
    Label(new, text='\n After tenth u can do:\n', font=("Times", 20),fg="black").pack() 
    twelth_button = Button(new, text='12th', fg='#6ab04c', width=16, bg="White", font=("Comic sans ms", 16), command=twelth).pack(pady=20, padx=10)
    iti_button= Button(new, text='ITI', fg='#6ab04c', width=16, bg="White", font=("Comic sans ms", 16), command=iti).pack(pady=20, padx=10)
    back_button = Button(new, text='Back', fg='#6ab04c', width=10, bg="White", font=("Comic sans ms", 10), command=gui).pack(pady=20, padx=10)

    
def twelth():
    new=Tk()
    new.title('twelth_streams')
    new.geometry('500x500')
    Label(new, text='Streams in 12th are :', font=("Times", 20),fg="Black").grid(row=1,column=2)
    Label(new, text='MEDICAL', font=("Times", 15),fg="black").grid(row=4,column=1)
    Label(new, text='Non-Medical', font=("Times", 15),fg="black").grid(row=4,column=3)
    Label(new, text='Commerce', font=("Times", 15),fg="black").grid(row=8,column=2)
    Label(new, text='ART', font=("Times", 15),fg="red").grid(row=8,column=4)
    Home_button = Button(new, text='HOME', fg='#6ab04c', width=10, bg="White", font=("Comic sans ms", 10), command=gui).grid(row=16, column=4)
    back_button = Button(new, text='Back', fg='#6ab04c', width=10, bg="White", font=("Comic sans ms", 10), command=tenth).grid(row=16, column=1)


def iti():
    new=Tk()
    new.title('Iti')
    new.geometry('500x500')
    Label(new, text='ITI', font=("Times", 20),fg="red").grid(column=2)
    Label(new, text='Name of courses', font=("Times", 15),fg="black",bg='yellow').grid(row=1,column=1)
    Label(new, text='Droughts man engineering', font=("Times", 10),fg="black").grid(row=2,column=1)
    Label(new, text='Pump operator', font=("Times", 10),fg="black").grid(row=3,column=1)
    Label(new, text='Filter Engeneering', font=("Times", 10),fg="black").grid(row=4,column=1)
    Label(new, text='Dress Making', font=("Times", 10),fg="black").grid(row=5,column=1)
    Label(new, text='Electrician Engineering', font=("Times", 10),fg="black").grid(row=6,column=1)
    Label(new, text='Commercial Art', font=("Times", 10),fg="black").grid(row=7,column=1)
    Label(new, text='Hand compositer', font=("Times", 10),fg="black").grid(row=8,column=1)
    Label(new, text='surveyor Engineering', font=("Times", 10),fg="black").grid(row=9,column=1)
    
    Label(new, text='Streams', font=("Times", 15),fg="black",bg='yellow').grid(row=1,column=2)
    Label(new, text='Engineering', font=("Times", 10),fg="black").grid(row=2,column=2)
    Label(new, text='Engineering', font=("Times", 10),fg="black").grid(row=3,column=2)
    Label(new, text='Engeneering', font=("Times", 10),fg="black").grid(row=4,column=2)
    Label(new, text='Non-Engineering', font=("Times", 10),fg="black").grid(row=5,column=2)
    Label(new, text='Engineering', font=("Times", 10),fg="black").grid(row=6,column=2)
    Label(new, text='Non-Engineering', font=("Times", 10),fg="black").grid(row=7,column=2)
    Label(new, text='Non-Engineering', font=("Times", 10),fg="black").grid(row=8,column=2)
    Label(new, text='Engineering', font=("Times", 10),fg="black").grid(row=9,column=2)
    
    
    Label(new, text='Duration', font=("Times", 15),fg="black",bg='yellow').grid(row=1,column=3)
    Label(new, text='   2', font=("Times", 10),fg="black").grid(row=2,column=3)
    Label(new, text='   2', font=("Times", 10),fg="black").grid(row=3,column=3)
    Label(new, text='   2', font=("Times", 10),fg="black").grid(row=4,column=3)
    Label(new, text='   2', font=("Times", 10),fg="black").grid(row=5,column=3)
    Label(new, text='   2', font=("Times", 10),fg="black").grid(row=6,column=3)
    Label(new, text='   1', font=("Times", 10),fg="black").grid(row=7,column=3)
    Label(new, text='   1', font=("Times", 10),fg="black").grid(row=8,column=3)
    Label(new, text='   2', font=("Times", 10),fg="black").grid(row=9,column=3)
    Home_button = Button(new, text='HOME', fg='#6ab04c', width=10, bg="White", font=("Comic sans ms", 10), command=gui).grid(row=16, column=4)

    
def new_user():
    new = Tk()
    new.title('registration')
    new.geometry('400x400')
    f = open("database_proj", 'a+')
    def msg():
        
        e2 = entry2.get()
    
        e4 = entry4.get() 
        e5 = entry5.get()
        
        entry2.delete(0, END)
        
        entry4.delete(0, END)
        entry5.delete(0, END)
        f.write(' {0}  {1} {2}\n'.format(str(e2), e4, e5))
        messagebox.showinfo("submittd","info submitted successfully" )
        gui()
        f.close()
    Label(new, text='enter your information', font=("Times", 20)).grid(row=0, pady=20)

    Label(new, text='name').grid(row=2)
    entry2 = Entry(new, font=("Times", 12))
    entry2.grid(row=2, column=1)


    Label(new, text='gender').grid(row=4)
    c1 = Checkbutton(new, text="male", onvalue=1, offvalue=0).grid(row=4, column=1)
    c2 = Checkbutton(new, text="female", onvalue=1, offvalue=0).grid(row=5, column=1)
    Label(new, text='mobile number').grid(row=6)
    entry4 = Entry(new, font=("Times", 12))
    entry4.grid(row=6, column=1)

    Label(new, text='email id').grid(row=7)
    entry5 = Entry(new, font=("Times", 12))
    entry5.grid(row=7, column=1, pady=20)

    Button(new, text='submit', fg='green', command=msg).grid(row=8, column=1)
    Button(new, text='cancel', fg='green', command=new.destroy).grid(row=8, column=0)
def login():
    lg = Tk()
    lg.title('login ')
    lg.geometry('500x500')
    def check():
        c = pd.get()
        if(c == "toor"):
            messagebox.showinfo("submittd", "login successfully")
            gui()
        else:
            messagebox.showinfo("submittd", "login failed\n try again")

    Label(lg, text='login', font=("Times", 25)).grid(row=0)
    Label(lg, text='user name').grid(row=2, pady=20)
    user = Entry(lg, font=("Times", 16))
    user.grid(row=2, column=1)

    Label(lg, text='password').grid(row=3, pady=20)
    pd = Entry(lg, font=("Times", 16))
    pd.grid(row=3, column=1)
    pd.configure(show="*")

    Button(lg, text='login', fg='green',command=check).grid(row=4, column=1)
    Button(lg, text='new user', fg='green', command=new_user).grid(row=4, column=0)
login_button = Button(frame, text='login', fg='#6ab04c', width=16, bg="White", font=("Comic sans ms", 16), command=login).pack(pady=20, padx=10)
newuser_button =Button(frame, text='new user', fg='#6ab04c', width=15, bg="White", font=("Comic sans ms", 16), command=new_user).pack(pady=20, padx=10)
root.mainloop()
